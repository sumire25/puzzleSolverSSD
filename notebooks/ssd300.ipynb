# %%
import getpass
import os

# Securely input your GitHub details
user = "sumire25"
repo = "puzzleSolverSSD"
token = getpass.getpass('Enter your GitHub Personal Access Token: ')

# Clone using the authenticated URL format
# !git clone https://{user}:{token}@://github.com{user}/{repo}.git

# Move into the repository directory
# %cd {repo}

# %%
# %%bash
# # 1. Identity yourself to Git (Required for committing)
# git config --global user.email "msumirer@unsa.edu.pe"
# git config --global user.name "sumire25"
#
# # 2. Stage and commit the changes
# git add .
# git commit -m "Updated files directly from Google Colab"
#
# # 3. Push back to the repository (usually 'main' or 'master')
# git push origin main
